# %%
# %matplotlib inline

import os
os.system('/usr/bin/Xvfb :99 -screen 0 1024x768x24 &')
os.environ['DISPLAY'] = ':99'

import panel as pn
pn.extension('vtk')

from helper import interactive_plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
interactive_plot(True)

# %%
interactive_plot(False)
